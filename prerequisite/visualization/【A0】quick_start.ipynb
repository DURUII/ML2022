# %% [markdown]
# # Set up the notebook

# %%
import numpy as np
import scienceplots
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# /Users/durui/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Setup Complete

# %% [markdown]
# # Practice

# %%
import pandas as pd

plt.style.use(['science', 'notebook', 'grid'])

data=pd.read_excel('Attachment 2.xlsx')
t=data.values[:,0]
T1=data.values[:,1]
T2=data.values[:,2]

fig, ax = plt.subplots(1, 1,figsize=(20,8))
ax.plot(t,T1,label="No.1 thermocouple")
ax.plot(t,T2,label="No.2 thermocouple")
ax.set_xlim((-10,600))
ax.set_ylim((800,1800))
ax.set_xlabel("Time [s]")
ax.set_ylabel("temperature [℃]")
ax.legend()
ax.set_title("1#wire temperature-2#wire temperature-time diagram")

plt.savefig("t1.svg")

# %%
import pandas as pd

plt.style.use(['science', 'notebook', 'grid'])

data=pd.read_excel('Attachment 2.xlsx')
t=data.values[:,0]
T1=data.values[:,1]
T2=data.values[:,2]

fig, ax = plt.subplots(1, 1,figsize=(20,8))
ax.plot(t,(T1+T2)/2,label="No.1&2 avrg thermocouple")

ax.set_xlim((-10,600))
ax.set_ylim((800,1800))
ax.set_xlabel("Time [s]")
ax.set_ylabel("temperature [℃]")
ax.legend()
ax.set_title("1#wire average temperature-2#wire average temperature-time diagram")

plt.savefig("t2.svg")

# %% [markdown]
# # Basic

# %% [markdown]
# ##  Trends

# %%
# Path of the file to read
filepath = "Attachment 2.xlsx"

# Read the file into a variable data
data = pd.read_excel(filepath, index_col="NO")

# Examine the data
# print(list(data.columns))
# print(data.head())
# print(data.tail())

# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=data)
plt.show()

# %%
x = np.linspace(0, 15, 30)
y = np.sin(x)+0.1*np.random.randn(len(x))
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, "o--", color="red", lw=2, ms=5)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(x, y, "o--", color="red", lw=2, ms=5)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(x, y, "o--", color="red", lw=2, ms=5)
plt.xlabel("Time [s]")
plt.ylabel("Voltage [V]")
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(x, y, "o--", color="red", lw=2, ms=5, label="Component 1")
plt.xlabel("Time [s]")
plt.ylabel("Voltage [V]")
plt.legend(loc="upper right", fontsize=10)
plt.show()

# %%
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

plt.figure(figsize=(10, 4))
plt.plot(x, y, "o", color="red", lw=2, ms=5, label="Component 1")
plt.plot(x2, y2, "-", color="blue", lw=2, ms=5, label="Component 2")
plt.xlabel("Time [s]")
plt.ylabel("Voltage [V]")
plt.legend(loc="upper right", fontsize=10)
plt.show()

# %%
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

plt.figure(figsize=(10, 4))
plt.plot(x, y, "o", color="red", lw=2, ms=5, label="Data")
plt.plot(x2, y2, "-", color="blue", lw=2, ms=5, label="Ground")
plt.xlabel("Time [s]")
plt.ylabel("Voltage [V]")
plt.ylim(top=1.5)
plt.legend(loc="upper right", fontsize=10, ncol=2)
plt.show()

# %% [markdown]
# ## Relationship

# %%
# Path of the file to read
insurance_filepath = "insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
# Out:
# /Users/durui/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 45.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# ## Distribution

# %%
res = np.random.randn(1000)*0.2+0.4
sns.histplot(res)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("dark")
# KDE plot
sns.kdeplot(data=res, fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")
#
# NameError: name 'iris_data' is not defined

# %%
a = plt.hist(res)
a
# Out:
# (array([ 15.,  24.,  53., 137., 198., 214., 168., 116.,  59.,  16.]),
#  array([-0.1751081 , -0.06771021,  0.03968768,  0.14708557,  0.25448346,
#          0.36188134,  0.46927923,  0.57667712,  0.68407501,  0.7914729 ,
#          0.89887079]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8, 3))
plt.hist(res, bins=30, density=True)
plt.show()

# %%
res2 = np.random.randn(1000)*0.2+0.4
plt.figure(figsize=(8, 3))
plt.hist(res, bins=30, density=True, histtype="step")
plt.hist(res2, bins=30, density=True, histtype="step")
plt.show()

# %%
sns.kdeplot(data=res, fill=True)
sns.kdeplot(data=res2, fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## Axes

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 4))
ax.plot(x, y, "o--")
ax.set_xlabel("Time [s]")
ax.set_ylabel("Voltage [V]")
# Out:
# Text(0, 0.5, 'Voltage [V]')

# %%
fig, axes = plt.subplots(3, 2, figsize=(6, 6))
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
ax = axes[0][0]
ax.plot(x, y, "o--")
ax.set_xlabel("Time [s]")
ax.set_ylabel("Voltage [V]")
ax.text(0.1, 0.1, "text1")
ax.text(0.1, 0.1, "text2", transform=ax.transAxes)
ax.tick_params(axis="both", labelsize=10)

ax2 = axes[1][1]
ax2.hist(res, bins=30, density=True, histtype="step", label="Comp 1")
ax2.legend()
ax2.set_title("Hist")

plt.show()

# %% [markdown]
# ### Example

# %%
res_a1 = 0.2*np.random.randn(1000)+0.4
res_a2 = 0.25*np.random.randn(1000)+0.4
res_b1 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.22*np.random.randn(1000)+0.3

# %%
# good habit: beforehand
textstr1 = '\n'.join((r'$\sigma_a=%.4f$' % (np.std(res_a1)),
                      r'$\sigma_b=%.4f$' % (np.std(res_b1))))

textstr1 = '\n'.join((r'$\sigma_a=%.4f$' % (np.std(res_a2)),
                      r'$\sigma_b=%.4f$' % (np.std(res_b2))))

# %%
fig,axes=plt.subplots(1,2,figsize=(10,3.5))

ax=axes[0]
ax.hist(res_a1,bins=30,density=True,histtype="step",label="a",color="blue")
ax.hist(res_b1,bins=30,density=True,histtype="step",label="b",color="red")
ax.text(0.05,0.81,textstr1,transform=ax.transAxes,bbox=dict(facecolor="white",edgecolor="black"))
ax.set_ylabel("Density")
ax.set_title("Trail 1")

ax=axes[1]
ax.hist(res_a2,bins=30,density=True,histtype="step",label="a",color="blue")
ax.hist(res_b2,bins=30,density=True,histtype="step",label="b",color="red")
ax.legend(loc="upper right",fancybox=False,edgecolor="black",fontsize=10)
ax.text(0.05,0.81,textstr1,transform=ax.transAxes,bbox=dict(facecolor="white",edgecolor="black"))
ax.set_title("Trail 2")


fig.text(0.5,-0.04,"$\Delta E$ [Joules]",ha="center",fontsize=20)
plt.show()

# %% [markdown]
# ## 2D Plot

# %% [markdown]
# We always have to use this special notation to select the indexing column.

# %%
# Path of the file to read
flight_filepath = "flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data['NK'])

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True,cmap="coolwarm")

# Add label for horizontal axis
plt.xlabel("Airline")
plt.show()

# %%
_ = np.linspace(-1,1,100)
x,y=np.meshgrid(_,_)
z=x**2+y*x

# %% [markdown]
# [Choosing Colormaps in Matplotlib](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
plt.contourf(x,y,z,vmax=1.68,cmap="plasma")
plt.colorbar(label="voltage")
cs=plt.contour(x,y,z,vmax=1.68,levels=20,cmap="Spectral")
plt.clabel(cs,fontsize=8)
# Out:
# /var/folders/hq/mrh1wvlx1r9crbtgy7q4hfbc0000gn/T/ipykernel_12852/2802793175.py:2: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(label="voltage")
# <a list of 28 text.Text objects>

# %% [markdown]
# ## 3D Surface Plot

# %%
fig,ax=plt.subplots(subplot_kw={'projection':"3d"})
ax.plot_surface(x,y,z,cmap="coolwarm")

# %% [markdown]
# ## StreamPlots

# %%
w=3
_=np.linspace(-3,3,100)
X,Y=np.meshgrid(_,_)
U=-1-X**2+Y
V=1+X-Y**2
speed=np.sqrt(U**2,V**2)

# %%
fig,axes=plt.subplots(2,2,figsize=(7,7))
ax=axes[0][0]
ax.streamplot(X,Y,U,V)

ax=axes[0][1]
ax.streamplot(X,Y,U,V,color=speed)

ax=axes[1][0]
lw=5*speed/speed.max()
ax.streamplot(X,Y,U,V,linewidth=lw)

ax=axes[1][1]
lw=5*speed/speed.max()
seedpoints=np.array([[0,1],[1,0]])
ax.streamplot(X,Y,U,V,start_points=seedpoints)

plt.savefig("plot.png",dpi=500)

# %% [markdown]
# ## Image

# %%
im=plt.imread("twitter.jpg")
plt.imshow(im)

# %% [markdown]
# ## Animation

# %%
def f(x,t):
    return np.sin(x-3*t)

x=np.linspace(0,10*np.pi,1000)

plt.plot(x,f(x,0))
plt.plot(x,f(x,1.3))

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

fig,ax=plt.subplots(1,1,figsize=(8,4))

ln1,=plt.plot([],[])

time_text=plt.text(0.65,0.95,"",fontsize=15,
    transform=ax.transAxes,bbox=dict(facecolor="white",edgecolor="black"))

ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5,1.5)

def animate(i):
    ln1.set_data(x,f(x,1/50*i))
    time_text.set_text("t={:.2f}".format(i/50))

ani = animation.FuncAnimation(fig,animate,frames=240,interval=50)
ani.save("ani.gif",writer="pillow",fps=50,dpi=100)

# %%
_ = np.linspace(-1,1,100)
x,y=np.meshgrid(_,_)
z=x**2+y*x

plt.style.use(['default'])

fig,ax=plt.subplots(subplot_kw={'projection':'3d'})

ax.plot_surface(x,y,z,cmap="coolwarm",linewidth=0,antialiased=False)
ax.view_init(elev=10,azim=0)

def animate(i):
    ax.view_init(elev=10,azim=3*i)
    
ani = animation.FuncAnimation(fig,animate,frames=120,interval=50)
ani.save("ani.gif",writer="pillow",fps=30,dpi=100)
